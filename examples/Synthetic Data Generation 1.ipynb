# %% [markdown]
# # Synthetic Data Generation

# %%
import json
import sys
import csv
sys.path.append('..')


import tinytroupe
from tinytroupe.agent import TinyPerson
from tinytroupe.environment import TinyWorld, TinySocialNetwork
from tinytroupe.factory import TinyPersonFactory
from tinytroupe.extraction import ResultsReducer
import tinytroupe.control as control
# Out:
# !!!!
# DISCLAIMER: TinyTroupe relies on Artificial Intelligence (AI) models to generate content.
# The AI models are not perfect and may produce inappropriate or inacurate results.
# For any serious or consequential use, please review the generated content before using it.
# !!!!
#
# Looking for default config on: c:\Users\pdasilva\repos\TinyTroupe\examples\..\tinytroupe\utils\..\config.ini
# Found custom config on: c:\Users\pdasilva\repos\TinyTroupe\examples\config.ini
# TinyTroupe version: 0.6.0
# Current date and time (local): 2026-01-25 19:34:45
# Current date and time (UTC):   2026-01-25 22:34:45
#
# =================================
# Current TinyTroupe configuration
# =================================
# [OpenAI]
# api_type = openai
# azure_api_version = 2024-08-01-preview
# model = gpt-5-mini
# reasoning_model = o3-mini
# embedding_model = text-embedding-3-small
# azure_embedding_model_api_version = 2023-05-15
# max_completion_tokens = 128000
# timeout = 480
# max_attempts = 5
# waiting_time = 0
# exponential_backoff_factor = 5
# max_concurrent_model_calls = 4
# reasoning_effort = high
# cache_api_calls = False
# cache_file_name = openai_api_cache.pickle
# max_content_display_length = 1024
#
# [Simulation]
# parallel_agent_generation = True
# parallel_agent_actions = True
# rai_harmful_content_prevention = True
# rai_copyright_infringement_prevention = True
#
# [Cognition]
# enable_memory_consolidation = True
# enable_continuous_contextual_semantic_memory_retrieval = True
# min_episode_length = 10
# max_episode_length = 15
# episodic_memory_fixed_prefix_length = 10
# episodic_memory_lookback_length = 20
#
# [ActionGenerator]
# max_attempts = 2
# enable_quality_checks = False
# enable_regeneration = True
# enable_direct_correction = False
# enable_quality_check_for_persona_adherence = True
# enable_quality_check_for_selfconsistency = False
# enable_quality_check_for_fluency = False
# enable_quality_check_for_suitability = False
# enable_quality_check_for_similarity = False
# continue_on_failure = True
# quality_threshold = 5
#
# [Logging]
# loglevel = ERROR
# loglevel_console = INFO
# loglevel_file = DEBUG
# log_include_thread_id = True
#
# 2026-01-25 19:34:52,874 - MainThread(18540) - numexpr.utils - INFO - NumExpr defaulting to 8 threads.

# %% [markdown]
# Let's create the specific types of agents we need to collect data.

# %%
factory = TinyPersonFactory("A random knowledge worker in a company providing marketing services.")

# %%
people = []
for i in range(2):
    person = factory.generate_person(temperature=1.6)
    print(person.minibio())
    people.append(person)

len(people)
# Out:
# 2026-01-25 19:35:35,061 - MainThread(18540) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:35:35,091 - MainThread(18540) - tinytroupe - INFO - Generating person with the following particularities: Full name: Marina Ellsworth | already_generated_names: [] | context: null | reasoning: selected a realistic, culturally neutral full name (given name + surname) that is not present in the provided list and sounds natural.
# 2026-01-25 19:35:35,582 - MainThread(18540) - tinytroupe - WARNING - gpt-5 only supports temperature=1.0, removing custom temperature=1.6
# 2026-01-25 19:36:55,718 - MainThread(18540) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:37:06,567 - MainThread(18540) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Marina Ellsworth is a 34 year old IT Systems Analyst / Consultant (Mid-level), American, currently living in Seattle, Washington, USA. Calm, deliberate, and approachable, Marina is a measured communicator and empathetic listener who prefers plain language and analogies, runs tight facilitation sessions, and follows up meetings with polite, bullet-pointed emails and clear next steps. Outside of work she carves out time for analog photography (regular darkroom Saturdays), weekend hikes and trail-maintenance volunteering, farmers' markets and seasonal baking, and tending a small balcony vegetable bed while collecting vintage municipal maps. She firmly believes privacy is a human right, favors small iterative improvements and strong documentation over flashy solutions, and routinely mentors early-career professionals while applying a skeptical, evidence-first approach to vendor selection. To keep sustainable momentum she maintains habits like a morning pour-over ritual, a weekly no-meeting deep-work day, journaling, and a practice of publicly celebrating small project wins.
# 2026-01-25 19:37:23,933 - MainThread(18540) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:37:23,942 - MainThread(18540) - tinytroupe - INFO - Generating person with the following particularities: Full name: Natalia Carmichael
# 2026-01-25 19:37:24,420 - MainThread(18540) - tinytroupe - WARNING - gpt-5 only supports temperature=1.0, removing custom temperature=1.6
# 2026-01-25 19:38:41,683 - MainThread(18540) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:38:54,346 - MainThread(18540) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Natalia Carmichael is a 34 year old High School Biology Teacher (Grades 9-12), British-American, currently living in Seattle, Washington, USA. She’s warm and quietly exact — using short, structured cues and wry analogies to make tricky ideas feel accessible, and she’s patient with learners while firmly enforcing safety and fairness. Off duty she’s a hands-on naturalist and maker: gardening a pollinator patch, photographing macro and seasonal scenes, baking sourdough, refurbishing bird boxes, and collecting seed envelopes and field notes that feed into her lessons. Professionally she’s skilled at designing inquiry-based labs (microscopy, basic PCR concepts, water testing), curriculum mapping, grant-writing for classroom equipment, and mentoring colleagues while keeping digital resources organized in Canvas. Longer term she hopes to move into curriculum leadership and teacher-coaching, write a practical guide on ecology and climate literacy for classrooms, and restore an older home with a demonstrative garden.
# 2

# %%
company = TinyWorld("Some Corp Inc.", people)

# %%
company.make_everyone_accessible()

# %%
company.broadcast("Get some work done together, help each other.")
# Out:
# USER --> Marina Ellsworth: [CONVERSATION]
#           > Get some work done together, help each other.
#        + --> Natalia Carmichael

# %%
company.run(5)
# Out:
# 2026-01-25 19:38:54,563 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] Running world simulation step 1 of 5.
# ─────────────────────────────────────────── Some Corp Inc. step 1 of 5 ────────────────────────────────────────────
# 2026-01-25 19:38:54,572 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] No timedelta provided, so the datetime was not advanced.
# 2026-01-25 19:39:13,622 - ThreadPoolExecutor-0_0(35856) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Marina Ellsworth acts: [THINK]
#                       > They want to get work done together. Best approach: propose a short,
#                       > structured co-working session with a clear agenda, timebox, and an offer of
#                       > concrete help. Keep it flexible (90-minute block or two 45-minute
#                       > Pomodoros), list the kinds of help I can offer (requirements drafting,
#                       > acceptance criteria, data-cleaning, editing, vendor scoring), and ask which
#                       > task they want to start with and their time preference. Prepare to open a
#                       > shared doc and set a timer if they agree.
# Marina Ellsworth acts: [TALK]
#                       > Sounds good — I’m up for a focused co-working session. Quick proposal: a
#                       > 90‑minute block (or 2×45 Pomodoros) with this agenda: 1) pick 1–2 priority
#                       > tasks and clarify the desired outcome, 2) pair on the
#                       > highest‑priority/hardest item for the first 45–60 minutes, 3) 10–15 minute
#                       > check‑in to capture decisions and next steps. I can help draft requirements,
#                       > map acceptance criteria, clean or outline data steps, review text, or sketch
#                       > next actions. What would you like to work on first, and do you prefer 90
#                       > minutes or two 45‑minute rounds? If that works, I’ll open a shared doc and
#                       > set a timer.
# Marina Ellsworth acts: [DONE]
#                       > Waiting for your task choice and time preference.
# 2026-01-25 19:39:19,215 - ThreadPoolExecutor-0_1(63896) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Natalia Carmichael acts: [THINK]
#                         > Stimulus: 'Get some work done together, help each other.' I should respond
#                         > warmly and propose a clear, timeboxed plan so we actually make progress.
#                         > Options to offer: focused grading, lesson planning (next week's
#                         > diffusion/osmosis lab), Environmental Club prep, or a quick grant/proposal
#                         > draft. Prioritise grading + lesson prep because they have concrete, near
#                         > deadlines and benefit from paired accountability. Best workflow: brief
#                         > 5-minute check-in to agree priorities, then two focused blocks (I suggest
#                         > 25/5 Pomodoro blocks or a single 50-minute block if preferred). Offer to
#                         > share my Canvas folder and a rubric or a shared Google Doc. Ask which task
#                         > the partner prefers and which block length they want.
# Natalia Carmichael acts: [TALK]
#                         > Yes — I'd love to. First we will do a quick 5-minute check-in to agree
#                         > priorities. Then we will do a focused work block (I suggest 25 minutes
#                         > with a 5-minute break, then a second 25-minute block) — that usually helps
#                         > me stay on task. My priorities right now are grading a stack of lab
#                         > reports and finalising a Monday diffusion/osmosis lesson; either of those
#                         > would be great to tackle together. I can open a shared Google Doc or my
#                         > Canvas folder and share the rubric so we can work in parallel. Does that
#                         > plan suit you? Which task would you prefer to start with, and do you
#                         > prefer 25/5 Pomodoros or a single 50-minute block?
# Natalia Carmichael acts: [DONE]
#                         > Waiting for collaborator to confirm priorities and preferred work-block
#                         > length.
# Marina Ellsworth --> Natalia Carmichael: [CONVERSATION]
#                       > Sounds good — I’m up for a focused co-working session. Quick proposal: a
#                       > 90‑minute block (or 2×45 Pomodoros) with this agenda: 1) pick 1–2 priority
#                       > tasks and clarify the desired outcome, 2) pair on the
#                       > highest‑priority/hardest item for the first 45–60 minutes, 3) 10–15 minute
#                       > check‑in to capture decisions and next steps. I can help draft requirements,
#                       > map acceptance criteria, clean or outline data steps, review text, or sketch
#                       > next actions. What would you like to work on first, and do you prefer 90
#                       > minutes or two 45‑minute rounds? If that works, I’ll open a shared doc and
#                       > set a timer.
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Yes — I'd love to. First we will do a quick 5-minute check-in to agree
#                         > priorities. Then we will do a focused work block (I suggest 25 minutes
#                         > with a 5-minute break, then a second 25-minute block) — that usually helps
#                         > me stay on task. My priorities right now are grading a stack of lab
#                         > reports and finalising a Monday diffusion/osmosis lesson; either of those
#                         > would be great to tackle together. I can open a shared Google Doc or my
#                         > Canvas folder and share the rubric so we can work in parallel. Does that
#                         > plan suit you? Which task would you prefer to start with, and do you
#                         > prefer 25/5 Pomodoros or a single 50-minute block?
# 2026-01-25 19:39:19,368 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] Running world simulation step 2 of 5.
# ─────────────────────────────────────────── Some Corp Inc. step 2 of 5 ────────────────────────────────────────────
# 2026-01-25 19:39:19,379 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] No timedelta provided, so the datetime was not advanced.
# 2026-01-25 19:39:41,351 - ThreadPoolExecutor-1_0(38260) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Marina Ellsworth acts: [THINK]
#                       > Natalia proposed a 5‑minute check‑in, then 25/5/25 blocks. I should be
#                       > flexible and accept that rhythm — it matches her preference and tends to
#                       > help. Which task to start with: the Monday diffusion/osmosis lesson is
#                       > time‑sensitive, so prioritizing that makes sense; grading can follow or be
#                       > interleaved if she prefers. For the first 25‑minute burst I can: 1) clarify
#                       > one or two learning objectives, 2) sketch a quick in‑class activity and an
#                       > exit ticket, 3) note materials/accommodations and slide/speaker notes. After
#                       > that block we can use the 5‑minute break to trade quick feedback and then
#                       > either iterate or switch to grading. I should offer to open a shared Google
#                       > Doc (or use her Canvas folder) and ask for the link, assign roles for the
#                       > first block, and start the 5‑minute check‑in now. Keep language supportive
#                       > and concrete.
# Marina Ellsworth acts: [TALK]
#                       > Sounds great — I like the 5‑minute check‑in + 25/5/25 rhythm. I suggest we
#                       > start with finalizing your Monday diffusion/osmosis lesson (time‑sensitive),
#                       > unless you’d rather begin with the grading stack. Proposed plan for the
#                       > first 25‑minute block (I can take the lead drafting these):  1) Confirm 1–2
#                       > clear learning objectives for Monday (what students should be able to DO).
#                       > 2) Sketch a 15–20 minute core activity (hands‑on demo or guided simulation)
#                       > and a 5‑minute exit ticket question to assess learning.  3) Make a short
#                       > materials/tech checklist and a note about accessibility/accommodations.  4)
#                       > Jot a very brief teacher script/slide notes and any quick formative
#                       > assessment items.  After the first 25 minutes we’ll take the 5‑minute break,
#                       > then use the second 25‑minute block to refine the activity, turn the exit
#                       > ticket into an assessment item, or switch to grading if you prefer.
#                       > Practicals: do you want me to open a Google Doc, or will you share a Canvas
#                       > page? If Google Doc works, I can create an outline and past (...)
# Marina Ellsworth acts: [DONE]
#                       > Waiting for Natalia to confirm task choice and share the doc/link so we can
#                       > start the 5‑minute check‑in.
# 2026-01-25 19:39:45,738 - ThreadPoolExecutor-1_1(63440) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Natalia Carmichael acts: [THINK]
#                         > Marina proposes a 90-minute block or 2x45s. I should accept the 90-minute
#                         > option (two focused 45-minute rounds) since that gives enough time for a
#                         > substantive first pairing and a clear second task. My priorities remain:
#                         > clear a chunk of grading and then finalise the Monday diffusion/osmosis
#                         > lesson. I need to set concrete acceptance criteria so the session is
#                         > productive (e.g., complete a first-pass on 20 lab reports with three-
#                         > bullet feedback each, or finish slides + materials list + an exit ticket
#                         > for the lesson). I'll ask Marina to open a shared Google Doc and set a
#                         > 45-minute timer to start; I'll paste the rubric from Canvas into the doc
#                         > and work in parallel. Tone: warm but precise, structured language
#                         > (First..., Then..., Finally...).
# Natalia Carmichael acts: [TALK]
#                         > Lovely — that plan suits me. First we will do a 90-minute block made of
#                         > two focused 45-minute rounds, then a 10–15 minute check-in to capture
#                         > decisions and next steps. My suggestion for priorities: start with grading
#                         > the lab reports (they're the most urgent), then use the second 45 to
#                         > finalise Monday's diffusion/osmosis lesson. Acceptance criteria so we're
#                         > aligned: for grading, I'll aim for a first-pass on ~20 reports with my
#                         > three-bullet feedback structure (praise, one improvement, next step) or at
#                         > least complete the first pass on the stack and flag any tricky ones; for
#                         > the lesson, I'd like finished slides, a materials list, and a short exit
#                         > ticket uploaded to Canvas. Could you open a shared Google Doc and set a
#                         > 45-minute timer to start? I can paste my rubric from Canvas into the doc
#                         > and work in parallel — would you prefer to draft comments while I skim for
#                         > trends, or should we split by batches and swap responsibility after the
#                         > first round?
# Natalia Carmichael acts: [DONE]
#                         > Waiting to begin the first 45-minute focused round once Marina opens the
#                         > shared doc and starts the timer.
# Marina Ellsworth --> Natalia Carmichael: [CONVERSATION]
#                       > Sounds great — I like the 5‑minute check‑in + 25/5/25 rhythm. I suggest we
#                       > start with finalizing your Monday diffusion/osmosis lesson (time‑sensitive),
#                       > unless you’d rather begin with the grading stack. Proposed plan for the
#                       > first 25‑minute block (I can take the lead drafting these):  1) Confirm 1–2
#                       > clear learning objectives for Monday (what students should be able to DO).
#                       > 2) Sketch a 15–20 minute core activity (hands‑on demo or guided simulation)
#                       > and a 5‑minute exit ticket question to assess learning.  3) Make a short
#                       > materials/tech checklist and a note about accessibility/accommodations.  4)
#                       > Jot a very brief teacher script/slide notes and any quick formative
#                       > assessment items.  After the first 25 minutes we’ll take the 5‑minute break,
#                       > then use the second 25‑minute block to refine the activity, turn the exit
#                       > ticket into an assessment item, or switch to grading if you prefer.
#                       > Practicals: do you want me to open a Google Doc, or will you share a Canvas
#                       > page? If Google Doc works, I can create an outline and past (...)
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Lovely — that plan suits me. First we will do a 90-minute block made of
#                         > two focused 45-minute rounds, then a 10–15 minute check-in to capture
#                         > decisions and next steps. My suggestion for priorities: start with grading
#                         > the lab reports (they're the most urgent), then use the second 45 to
#                         > finalise Monday's diffusion/osmosis lesson. Acceptance criteria so we're
#                         > aligned: for grading, I'll aim for a first-pass on ~20 reports with my
#                         > three-bullet feedback structure (praise, one improvement, next step) or at
#                         > least complete the first pass on the stack and flag any tricky ones; for
#                         > the lesson, I'd like finished slides, a materials list, and a short exit
#                         > ticket uploaded to Canvas. Could you open a shared Google Doc and set a
#                         > 45-minute timer to start? I can paste my rubric from Canvas into the doc
#                         > and work in parallel — would you prefer to draft comments while I skim for
#                         > trends, or should we split by batches and swap responsibility after the
#                         > first round?
# 2026-01-25 19:39:46,071 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] Running world simulation step 3 of 5.
# ─────────────────────────────────────────── Some Corp Inc. step 3 of 5 ────────────────────────────────────────────
# 2026-01-25 19:39:46,079 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] No timedelta provided, so the datetime was not advanced.
# 2026-01-25 19:40:04,985 - ThreadPoolExecutor-2_0(58348) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Marina Ellsworth acts: [THINK]
#                       > Natalia wants a 90-minute block (2x45) with grading first. Best to accept
#                       > and be concrete about roles. Drafting comments while she skims for trends is
#                       > efficient and plays to my strengths in clear writing. I should offer a
#                       > simple batch split (I take the first ~10 reports and draft the three-bullet
#                       > feedback; she pastes the rubric and flags tricky ones). Create a shared
#                       > Google Doc, paste a brief outline (roles, timer, acceptance criteria), and
#                       > start a 45-minute timer. Confirm swap or handoff at the end of the 45 to
#                       > capture any tricky reports and next steps. Keep tone collaborative and ask
#                       > for confirmation to start.
# Marina Ellsworth acts: [TALK]
#                       > That plan sounds good — I can do the Google Doc and kick off the first
#                       > 45-minute timer. My suggested workflow to keep us coordinated: 1) You paste
#                       > the rubric at the top of the doc and flag any reports you already see as
#                       > tricky. 2) I’ll draft the three-bullet feedback (praise, one improvement,
#                       > next step) for roughly the first ~10 reports while you skim for trends and
#                       > paste any global notes. 3) At the 45-minute mark we’ll do a quick 3–5 minute
#                       > check-in in the doc: capture tricky ones, swap batches if needed, or finish
#                       > the pass. That should get you a solid first pass on the stack; if the pile
#                       > is larger we can adjust in the midpoint. I’ll create the doc now and share
#                       > the link here — do you want me to name the doc “Lab grading — first pass
#                       > ” and start the timer when you confirm?
# Marina Ellsworth acts: [DONE]
#                       > Waiting for Natalia to confirm and paste the rubric so I can create the
#                       > Google Doc and start the 45-minute timer.
# 2026-01-25 19:40:09,828 - ThreadPoolExecutor-2_1(25272) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Natalia Carmichael acts: [THINK]
#                         > Marina's 25/5/25 rhythm will work well for a time-sensitive lesson and
#                         > keeps things focused. I should accept Google Doc (easier than messing with
#                         > Canvas links during a live session), set clear roles and acceptance
#                         > criteria for each 25-minute block, and ask her to start a 5-minute check-
#                         > in/timer. Keep language structured: First..., Then..., Finally....
# Natalia Carmichael acts: [TALK]
#                         > Lovely — the 25/5/25 rhythm suits me and I agree we should start with the
#                         > Monday diffusion/osmosis lesson. First, can you open a Google Doc and
#                         > share the link? I’ll paste the Canvas rubric into it so we have the
#                         > success criteria visible. Roles for the first 25-minute block: please take
#                         > the lead drafting the 15–20 minute core activity (hands-on demo or guided
#                         > simulation) and a provisional materials/tech checklist; I’ll draft 1–2
#                         > clear learning objectives, note accessibility/accommodations, and add a
#                         > brief teacher script/slide notes. Acceptance criteria for the first 25:
#                         > agreed learning objectives, a sketched core activity, and a materials
#                         > checklist (flag any missing or tricky supplies). Then in the second
#                         > 25-minute block I’ll turn the exit ticket into a formative assessment item
#                         > and assemble 3–6 slides + a short teacher script while you refine the
#                         > activity and check logistics. Finally, we’ll use the short check-in after
#                         > both blocks to capture decisions and upload the exit ticket/slides to
#                         > Canvas. Ready for you (...)
# Natalia Carmichael acts: [DONE]
#                         > Waiting for Marina to open the Google Doc and start the 5-minute check-
#                         > in/timer.
# 2026-01-25 19:40:51,363 - ThreadPoolExecutor-2_0(58348) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:40:51,419 - ThreadPoolExecutor-2_0(58348) - tinytroupe - INFO - [Marina Ellsworth] Consolidating current 12 episodic events as consolidated semantic memories.
# 2026-01-25 19:40:55,919 - ThreadPoolExecutor-2_0(58348) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:40:56,244 - ThreadPoolExecutor-2_0(58348) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:40:56,561 - ThreadPoolExecutor-2_0(58348) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:40:56,870 - ThreadPoolExecutor-2_0(58348) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:40:57,210 - ThreadPoolExecutor-2_0(58348) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:40:57,537 - ThreadPoolExecutor-2_0(58348) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:41:06,214 - ThreadPoolExecutor-2_1(25272) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:41:06,292 - ThreadPoolExecutor-2_1(25272) - tinytroupe - INFO - [Natalia Carmichael] Consolidating current 12 episodic events as consolidated semantic memories.
# 2026-01-25 19:41:07,008 - ThreadPoolExecutor-2_1(25272) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:41:07,499 - ThreadPoolExecutor-2_1(25272) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:41:07,954 - ThreadPoolExecutor-2_1(25272) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:41:08,468 - ThreadPoolExecutor-2_1(25272) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:41:08,971 - ThreadPoolExecutor-2_1(25272) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-25 19:41:09,504 - ThreadPoolExecutor-2_1(25272) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Marina Ellsworth --> Natalia Carmichael: [CONVERSATION]
#                       > That plan sounds good — I can do the Google Doc and kick off the first
#                       > 45-minute timer. My suggested workflow to keep us coordinated: 1) You paste
#                       > the rubric at the top of the doc and flag any reports you already see as
#                       > tricky. 2) I’ll draft the three-bullet feedback (praise, one improvement,
#                       > next step) for roughly the first ~10 reports while you skim for trends and
#                       > paste any global notes. 3) At the 45-minute mark we’ll do a quick 3–5 minute
#                       > check-in in the doc: capture tricky ones, swap batches if needed, or finish
#                       > the pass. That should get you a solid first pass on the stack; if the pile
#                       > is larger we can adjust in the midpoint. I’ll create the doc now and share
#                       > the link here — do you want me to name the doc “Lab grading — first pass
#                       > ” and start the timer when you confirm?
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Lovely — the 25/5/25 rhythm suits me and I agree we should start with the
#                         > Monday diffusion/osmosis lesson. First, can you open a Google Doc and
#                         > share the link? I’ll paste the Canvas rubric into it so we have the
#                         > success criteria visible. Roles for the first 25-minute block: please take
#                         > the lead drafting the 15–20 minute core activity (hands-on demo or guided
#                         > simulation) and a provisional materials/tech checklist; I’ll draft 1–2
#                         > clear learning objectives, note accessibility/accommodations, and add a
#                         > brief teacher script/slide notes. Acceptance criteria for the first 25:
#                         > agreed learning objectives, a sketched core activity, and a materials
#                         > checklist (flag any missing or tricky supplies). Then in the second
#                         > 25-minute block I’ll turn the exit ticket into a formative assessment item
#                         > and assemble 3–6 slides + a short teacher script while you refine the
#                         > activity and check logistics. Finally, we’ll use the short check-in after
#                         > both blocks to capture decisions and upload the exit ticket/slides to
#                         > Canvas. Ready for you (...)
# 2026-01-25 19:41:09,564 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] Running world simulation step 4 of 5.
# ─────────────────────────────────────────── Some Corp Inc. step 4 of 5 ────────────────────────────────────────────
# 2026-01-25 19:41:09,571 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] No timedelta provided, so the datetime was not advanced.
# 2026-01-25 19:41:27,495 - ThreadPoolExecutor-3_1(55056) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:41:28,448 - ThreadPoolExecutor-3_1(55056) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Natalia Carmichael acts: [THINK]
#                         > Marina's workflow is clear and helpful. I should confirm the doc name,
#                         > accept her drafting role for the first batch, and restate my role (paste
#                         > rubric, flag tricky reports, skim for trends). Keep acceptance criteria
#                         > visible so the 45-minute mark yields clear next steps. Ask a quick
#                         > preference about comment format (inline three-bullet feedback vs. a
#                         > separate 'Feedback' column) to avoid confusion. Stay warm and concise.
# 2026-01-25 19:41:28,915 - ThreadPoolExecutor-3_1(55056) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Natalia Carmichael acts: [TALK]
#                         > Lovely — that sounds perfect. Yes, please name the doc "Lab grading
#                         > u000du000a— first pass 2026-01-25" (or similar) and share the link when
#                         > it's ready; start the timer when you confirm. First, I'll paste the Canvas
#                         > rubric at the top and flag any reports I already see as tricky. I'll skim
#                         > for trends while you draft the three-bullet feedback for the first ~10
#                         > reports (praise, one improvement, next step). Acceptance criteria for this
#                         > first pass: aim to complete a first-pass on the stack (rough target ~20
#                         > reports) with three-bullet feedback or at least finish the portion we
#                         > agree on and flag tricky ones for a second pass. One quick preference
#                         > question: do you want the three-bullet comments inline beneath each
#                         > report, or in a separate 'Feedback' column so we can filter/sort? Either
#                         > is fine with me — tell me which you prefer and then start the timer.
# 2026-01-25 19:41:29,319 - ThreadPoolExecutor-3_1(55056) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Natalia Carmichael acts: [DONE]
#                         > Waiting for Marina to share the Google Doc link, confirm comment format,
#                         > and start the timer.
# 2026-01-25 19:41:31,417 - ThreadPoolExecutor-3_0(18244) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:41:31,972 - ThreadPoolExecutor-3_0(18244) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Marina Ellsworth acts: [THINK]
#                       > Accept Natalia's plan and prepare to create a shared Google Doc. I'll set up
#                       > a simple outline that records roles, acceptance criteria, and the timer plan
#                       > (5-minute check-in, then 25/5/25 blocks). My immediate task in the first
#                       > 25-minute block is to draft the 15–20 minute core activity (hands-on demo or
#                       > guided simulation) and a provisional materials/tech checklist; she will
#                       > draft 1–2 learning objectives, accessibility notes, and a short teacher
#                       > script. I should name the doc clearly with the date so it's easy to find
#                       > (e.g., "Diffusion_Osmosis_Monday_2026-01-25"). Ask for edit permission if
#                       > needed and confirm start of the 5-minute check-in/timer. Keep tone
#                       > supportive and concrete.
# 2026-01-25 19:41:32,395 - ThreadPoolExecutor-3_0(18244) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Marina Ellsworth acts: [TALK]
#                       > Ready — I will open a Google Doc now and share the link here. I'll name it
#                       > "Diffusion_Osmosis_Monday_2026-01-25" and paste a short outline that
#                       > includes: 1) a 5-minute check-in note, 2) roles (I draft the 15–20-minute
#                       > core activity + materials/tech checklist; you draft 1–2 learning objectives,
#                       > accessibility notes, and teacher script), 3) acceptance criteria for the
#                       > first 25 (agreed objectives, sketched core activity, materials checklist),
#                       > and 4) the 25/5/25 timer plan. After I post the link, I’ll start the
#                       > 5-minute check-in timer. Do you want me to give you edit access (preferred)
#                       > or view-only? Any quick notes to add before I create the doc?
# 2026-01-25 19:41:32,892 - ThreadPoolExecutor-3_0(18244) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Marina Ellsworth acts: [DONE]
#                       > Creating the Google Doc and starting the 5-minute check-in once you confirm
#                       > edit access preference. Waiting for your quick notes or confirmation.
# Marina Ellsworth --> Natalia Carmichael: [CONVERSATION]
#                       > Ready — I will open a Google Doc now and share the link here. I'll name it
#                       > "Diffusion_Osmosis_Monday_2026-01-25" and paste a short outline that
#                       > includes: 1) a 5-minute check-in note, 2) roles (I draft the 15–20-minute
#                       > core activity + materials/tech checklist; you draft 1–2 learning objectives,
#                       > accessibility notes, and teacher script), 3) acceptance criteria for the
#                       > first 25 (agreed objectives, sketched core activity, materials checklist),
#                       > and 4) the 25/5/25 timer plan. After I post the link, I’ll start the
#                       > 5-minute check-in timer. Do you want me to give you edit access (preferred)
#                       > or view-only? Any quick notes to add before I create the doc?
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Lovely — that sounds perfect. Yes, please name the doc "Lab grading
#                         > u000du000a— first pass 2026-01-25" (or similar) and share the link when
#                         > it's ready; start the timer when you confirm. First, I'll paste the Canvas
#                         > rubric at the top and flag any reports I already see as tricky. I'll skim
#                         > for trends while you draft the three-bullet feedback for the first ~10
#                         > reports (praise, one improvement, next step). Acceptance criteria for this
#                         > first pass: aim to complete a first-pass on the stack (rough target ~20
#                         > reports) with three-bullet feedback or at least finish the portion we
#                         > agree on and flag tricky ones for a second pass. One quick preference
#                         > question: do you want the three-bullet comments inline beneath each
#                         > report, or in a separate 'Feedback' column so we can filter/sort? Either
#                         > is fine with me — tell me which you prefer and then start the timer.
# 2026-01-25 19:41:32,987 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] Running world simulation step 5 of 5.
# ─────────────────────────────────────────── Some Corp Inc. step 5 of 5 ────────────────────────────────────────────
# 2026-01-25 19:41:32,995 - MainThread(18540) - tinytroupe - INFO - [Some Corp Inc.] No timedelta provided, so the datetime was not advanced.
# 2026-01-25 19:41:54,245 - ThreadPoolExecutor-4_1(4232) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:41:54,903 - ThreadPoolExecutor-4_1(4232) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Natalia Carmichael acts: [THINK]
#                         > Marina will create the doc and start the timer. I should accept edit
#                         > access (makes live collaboration easier), remind her I'll paste the Canvas
#                         > rubric at the top, and ask for a simple 'Feedback' column so we can
#                         > filter/sort comments. Also remind her to flag any reports she already
#                         > thinks are tricky and to list any supplies that might need department
#                         > approval or substitution. Keep tone warm and structured: First...,
#                         > Then..., Finally....
# 2026-01-25 19:41:55,380 - ThreadPoolExecutor-4_1(4232) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Natalia Carmichael acts: [TALK]
#                         > Lovely — please give me edit access (that will be easiest). The document
#                         > name you suggested is fine. Quick notes: First, paste the Canvas rubric at
#                         > the top and I will add my copy as well so success criteria are visible.
#                         > Then, could you add a short 'Feedback' column (rather than burying
#                         > comments inline) so we can sort and filter the three-bullet feedback
#                         > easily? Please also flag any reports you already think are tricky and list
#                         > any materials that might need department approval or a substitute.
#                         > Finally, start the 5-minute check-in timer when you share the link and
#                         > I’ll join and paste my accessibility notes and learning-objective
#                         > suggestions. Ready when you are — thank you!
# 2026-01-25 19:41:55,941 - ThreadPoolExecutor-4_1(4232) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Natalia Carmichael acts: [DONE]
#                         > Waiting for the Google Doc link and for Marina to start the 5-minute
#                         > check-in timer.
# 2026-01-25 19:41:56,373 - ThreadPoolExecutor-4_0(24176) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-25 19:41:56,836 - ThreadPoolExecutor-4_0(24176) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Marina Ellsworth acts: [THINK]
#                       > Natalia asks about inline vs separate feedback and to name the doc. For
#                       > efficiency and later sorting/filtering I prefer a separate 'Feedback' column
#                       > (keeps the sheet machine-readable and makes it easy to export to Canvas or
#                       > filter flagged items). I'll create a Google Doc (table) named "Lab grading
#                       > u00096u00096 first pass 2026-01-25" or a Google Sheet if she prefers a true
#                       > columnar layout — ask which she prefers. Plan: 1) she pastes the Canvas
#                       > rubric at the top and flags tricky reports, 2) I'll take roughly reports
#                       > 1-10 and draft the three-bullet feedback (praise, one improvement, next
#                       > step) in the Feedback column, 3) add a 'Flag' column for tricky or
#                       > borderline reports, 4) at the 45-minute mark we'll do a 3-5 minute check-in
#                       > and swap batches if needed. Ask whether she wants me to also insert inline
#                       > comments in each original report file, or keep feedback only in the table to
#                       > avoid duplication. Start the timer when she confirms the rubric is pasted
#                       > and she's ready.
# 2026-01-25 19:41:57,355 - ThreadPoolExecutor-4_0(24176) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Marina Ellsworth acts: [TALK]
#                       > Thanks — I prefer a separate 'Feedback' column (easier to filter/sort and
#                       > export). I'll create a shared doc now titled "Lab grading u00096u00096 first
#                       > pass 2026-01-25" (or I can make a Google Sheet if you want strict columns).
#                       > Proposed structure: Report ID | Student name | Link to report | Feedback
#                       > (three bullets: praise, one improvement, next step) | Flag (tricky) | Notes.
#                       > Workflow: you paste the Canvas rubric at the top and flag any tricky ones;
#                       > I'll take roughly the first ~10 reports and draft the three-bullet feedback
#                       > in the Feedback column while you skim for trends. At the 45-minute mark
#                       > we'll do a 3–5 minute check-in and swap or continue as needed. Quick
#                       > question: do you want me to also add inline comments directly in the
#                       > original reports, or keep feedback only in the table to avoid duplication?
#                       > If that sounds good, confirm whether you prefer a Doc (table) or a Sheet,
#                       > paste the rubric, and I will start the timer as soon as you say go and give
#                       > me edit access.
# 2026-01-25 19:41:57,886 - ThreadPoolExecutor-4_0(24176) - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Marina Ellsworth acts: [DONE]
#                       > Waiting for your confirmation on Doc vs Sheet, the pasted rubric, and edit
#                       > access so I can create the file and start the 45-minute timer.
# Marina Ellsworth --> Natalia Carmichael: [CONVERSATION]
#                       > Thanks — I prefer a separate 'Feedback' column (easier to filter/sort and
#                       > export). I'll create a shared doc now titled "Lab grading u00096u00096 first
#                       > pass 2026-01-25" (or I can make a Google Sheet if you want strict columns).
#                       > Proposed structure: Report ID | Student name | Link to report | Feedback
#                       > (three bullets: praise, one improvement, next step) | Flag (tricky) | Notes.
#                       > Workflow: you paste the Canvas rubric at the top and flag any tricky ones;
#                       > I'll take roughly the first ~10 reports and draft the three-bullet feedback
#                       > in the Feedback column while you skim for trends. At the 45-minute mark
#                       > we'll do a 3–5 minute check-in and swap or continue as needed. Quick
#                       > question: do you want me to also add inline comments directly in the
#                       > original reports, or keep feedback only in the table to avoid duplication?
#                       > If that sounds good, confirm whether you prefer a Doc (table) or a Sheet,
#                       > paste the rubric, and I will start the timer as soon as you say go and give
#                       > me edit access.
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Lovely — please give me edit access (that will be easiest). The document
#                         > name you suggested is fine. Quick notes: First, paste the Canvas rubric at
#                         > the top and I will add my copy as well so success criteria are visible.
#                         > Then, could you add a short 'Feedback' column (rather than burying
#                         > comments inline) so we can sort and filter the three-bullet feedback
#                         > easily? Please also flag any reports you already think are tricky and list
#                         > any materials that might need department approval or a substitute.
#                         > Finally, start the 5-minute check-in timer when you share the link and
#                         > I’ll join and paste my accessibility notes and learning-objective
#                         > suggestions. Ready when you are — thank you!

# %% [markdown]
# We can now extract the conversations, which form the synthetic corpus we wanted.

# %%
people[0].pp_current_interactions()
# Out:
# **** BEGIN SIMULATION TRAJECTORY FOR Marina Ellsworth ****
# Agent simulation trajectory event #0:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# USER --> Marina Ellsworth: [CONVERSATION]
#           > Get some work done together, help each other.
# Agent simulation trajectory event #1:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [THINK]
#                       > They want to get work done together. Best approach: propose a short,
#                       > structured co-working session with a clear agenda, timebox, and an offer of
#                       > concrete help. Keep it flexible (90-minute block or two 45-minute
#                       > Pomodoros), list the kinds of help I can offer (requirements drafting,
#                       > acceptance criteria, data-cleaning, editing, vendor scoring), and ask which
#                       > task they want to start with and their time preference. Prepare to open a
#                       > shared doc and set a timer if they agree.
# Agent simulation trajectory event #2:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [TALK]
#                       > Sounds good — I’m up for a focused co-working session. Quick proposal: a
#                       > 90‑minute block (or 2×45 Pomodoros) with this agenda: 1) pick 1–2 priority
#                       > tasks and clarify the desired outcome, 2) pair on the
#                       > highest‑priority/hardest item for the first 45–60 minutes, 3) 10–15 minute
#                       > check‑in to capture decisions and next steps. I can help draft requirements,
#                       > map acceptance criteria, clean or outline data steps, review text, or sketch
#                       > next actions. What would you like to work on first, and do you prefer 90
#                       > minutes or two 45‑minute rounds? If that works, I’ll open a shared doc and
#                       > set a timer.
# Agent simulation trajectory event #3:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [DONE]
#                       > Waiting for your task choice and time preference.
# Agent simulation trajectory event #4:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Yes — I'd love to. First we will do a quick 5-minute check-in to agree
#                         > priorities. Then we will do a focused work block (I suggest 25 minutes
#                         > with a 5-minute break, then a second 25-minute block) — that usually helps
#                         > me stay on task. My priorities right now are grading a stack of lab
#                         > reports and finalising a Monday diffusion/osmosis lesson; either of those
#                         > would be great to tackle together. I can open a shared Google Doc or my
#                         > Canvas folder and share the rubric so we can work in parallel. Does that
#                         > plan suit you? Which task would you prefer to start with, and do you
#                         > prefer 25/5 Pomodoros or a single 50-minute block?
# Agent simulation trajectory event #5:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [THINK]
#                       > Natalia proposed a 5‑minute check‑in, then 25/5/25 blocks. I should be
#                       > flexible and accept that rhythm — it matches her preference and tends to
#                       > help. Which task to start with: the Monday diffusion/osmosis lesson is
#                       > time‑sensitive, so prioritizing that makes sense; grading can follow or be
#                       > interleaved if she prefers. For the first 25‑minute burst I can: 1) clarify
#                       > one or two learning objectives, 2) sketch a quick in‑class activity and an
#                       > exit ticket, 3) note materials/accommodations and slide/speaker notes. After
#                       > that block we can use the 5‑minute break to trade quick feedback and then
#                       > either iterate or switch to grading. I should offer to open a shared Google
#                       > Doc (or use her Canvas folder) and ask for the link, assign roles for the
#                       > first block, and start the 5‑minute check‑in now. Keep language supportive
#                       > and concrete.
# Agent simulation trajectory event #6:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [TALK]
#                       > Sounds great — I like the 5‑minute check‑in + 25/5/25 rhythm. I suggest we
#                       > start with finalizing your Monday diffusion/osmosis lesson (time‑sensitive),
#                       > unless you’d rather begin with the grading stack. Proposed plan for the
#                       > first 25‑minute block (I can take the lead drafting these):  1) Confirm 1–2
#                       > clear learning objectives for Monday (what students should be able to DO).
#                       > 2) Sketch a 15–20 minute core activity (hands‑on demo or guided simulation)
#                       > and a 5‑minute exit ticket question to assess learning.  3) Make a short
#                       > materials/tech checklist and a note about accessibility/accommodations.  4)
#                       > Jot a very brief teacher script/slide notes and any quick formative
#                       > assessment items.  After the first 25 minutes we’ll take the 5‑minute break,
#                       > then use the second 25‑minute block to refine the activity, turn the exit
#                       > ticket into an assessment item, or switch to grading if you prefer.
#                       > Practicals: do you want me to open a Google Doc, or will you share a Canvas
#                       > page? If Google Doc works, I can create an outline and past (...)
# Agent simulation trajectory event #7:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [DONE]
#                       > Waiting for Natalia to confirm task choice and share the doc/link so we can
#                       > start the 5‑minute check‑in.
# Agent simulation trajectory event #8:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Lovely — that plan suits me. First we will do a 90-minute block made of
#                         > two focused 45-minute rounds, then a 10–15 minute check-in to capture
#                         > decisions and next steps. My suggestion for priorities: start with grading
#                         > the lab reports (they're the most urgent), then use the second 45 to
#                         > finalise Monday's diffusion/osmosis lesson. Acceptance criteria so we're
#                         > aligned: for grading, I'll aim for a first-pass on ~20 reports with my
#                         > three-bullet feedback structure (praise, one improvement, next step) or at
#                         > least complete the first pass on the stack and flag any tricky ones; for
#                         > the lesson, I'd like finished slides, a materials list, and a short exit
#                         > ticket uploaded to Canvas. Could you open a shared Google Doc and set a
#                         > 45-minute timer to start? I can paste my rubric from Canvas into the doc
#                         > and work in parallel — would you prefer to draft comments while I skim for
#                         > trends, or should we split by batches and swap responsibility after the
#                         > first round?
# Agent simulation trajectory event #9:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [THINK]
#                       > Natalia wants a 90-minute block (2x45) with grading first. Best to accept
#                       > and be concrete about roles. Drafting comments while she skims for trends is
#                       > efficient and plays to my strengths in clear writing. I should offer a
#                       > simple batch split (I take the first ~10 reports and draft the three-bullet
#                       > feedback; she pastes the rubric and flags tricky ones). Create a shared
#                       > Google Doc, paste a brief outline (roles, timer, acceptance criteria), and
#                       > start a 45-minute timer. Confirm swap or handoff at the end of the 45 to
#                       > capture any tricky reports and next steps. Keep tone collaborative and ask
#                       > for confirmation to start.
# Agent simulation trajectory event #10:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [TALK]
#                       > That plan sounds good — I can do the Google Doc and kick off the first
#                       > 45-minute timer. My suggested workflow to keep us coordinated: 1) You paste
#                       > the rubric at the top of the doc and flag any reports you already see as
#                       > tricky. 2) I’ll draft the three-bullet feedback (praise, one improvement,
#                       > next step) for roughly the first ~10 reports while you skim for trends and
#                       > paste any global notes. 3) At the 45-minute mark we’ll do a quick 3–5 minute
#                       > check-in in the doc: capture tricky ones, swap batches if needed, or finish
#                       > the pass. That should get you a solid first pass on the stack; if the pile
#                       > is larger we can adjust in the midpoint. I’ll create the doc now and share
#                       > the link here — do you want me to name the doc “Lab grading — first pass
#                       > ” and start the timer when you confirm?
# Agent simulation trajectory event #11:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [DONE]
#                       > Waiting for Natalia to confirm and paste the rubric so I can create the
#                       > Google Doc and start the 45-minute timer.
# Agent simulation trajectory event #12:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Lovely — the 25/5/25 rhythm suits me and I agree we should start with the
#                         > Monday diffusion/osmosis lesson. First, can you open a Google Doc and
#                         > share the link? I’ll paste the Canvas rubric into it so we have the
#                         > success criteria visible. Roles for the first 25-minute block: please take
#                         > the lead drafting the 15–20 minute core activity (hands-on demo or guided
#                         > simulation) and a provisional materials/tech checklist; I’ll draft 1–2
#                         > clear learning objectives, note accessibility/accommodations, and add a
#                         > brief teacher script/slide notes. Acceptance criteria for the first 25:
#                         > agreed learning objectives, a sketched core activity, and a materials
#                         > checklist (flag any missing or tricky supplies). Then in the second
#                         > 25-minute block I’ll turn the exit ticket into a formative assessment item
#                         > and assemble 3–6 slides + a short teacher script while you refine the
#                         > activity and check logistics. Finally, we’ll use the short check-in after
#                         > both blocks to capture decisions and upload the exit ticket/slides to
#                         > Canvas. Ready for you (...)
# Agent simulation trajectory event #13:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [THINK]
#                       > Accept Natalia's plan and prepare to create a shared Google Doc. I'll set up
#                       > a simple outline that records roles, acceptance criteria, and the timer plan
#                       > (5-minute check-in, then 25/5/25 blocks). My immediate task in the first
#                       > 25-minute block is to draft the 15–20 minute core activity (hands-on demo or
#                       > guided simulation) and a provisional materials/tech checklist; she will
#                       > draft 1–2 learning objectives, accessibility notes, and a short teacher
#                       > script. I should name the doc clearly with the date so it's easy to find
#                       > (e.g., "Diffusion_Osmosis_Monday_2026-01-25"). Ask for edit permission if
#                       > needed and confirm start of the 5-minute check-in/timer. Keep tone
#                       > supportive and concrete.
# Agent simulation trajectory event #14:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [TALK]
#                       > Ready — I will open a Google Doc now and share the link here. I'll name it
#                       > "Diffusion_Osmosis_Monday_2026-01-25" and paste a short outline that
#                       > includes: 1) a 5-minute check-in note, 2) roles (I draft the 15–20-minute
#                       > core activity + materials/tech checklist; you draft 1–2 learning objectives,
#                       > accessibility notes, and teacher script), 3) acceptance criteria for the
#                       > first 25 (agreed objectives, sketched core activity, materials checklist),
#                       > and 4) the 25/5/25 timer plan. After I post the link, I’ll start the
#                       > 5-minute check-in timer. Do you want me to give you edit access (preferred)
#                       > or view-only? Any quick notes to add before I create the doc?
# Agent simulation trajectory event #15:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [DONE]
#                       > Creating the Google Doc and starting the 5-minute check-in once you confirm
#                       > edit access preference. Waiting for your quick notes or confirmation.
# Agent simulation trajectory event #16:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Lovely — that sounds perfect. Yes, please name the doc "Lab grading
#                         > u000du000a— first pass 2026-01-25" (or similar) and share the link when
#                         > it's ready; start the timer when you confirm. First, I'll paste the Canvas
#                         > rubric at the top and flag any reports I already see as tricky. I'll skim
#                         > for trends while you draft the three-bullet feedback for the first ~10
#                         > reports (praise, one improvement, next step). Acceptance criteria for this
#                         > first pass: aim to complete a first-pass on the stack (rough target ~20
#                         > reports) with three-bullet feedback or at least finish the portion we
#                         > agree on and flag tricky ones for a second pass. One quick preference
#                         > question: do you want the three-bullet comments inline beneath each
#                         > report, or in a separate 'Feedback' column so we can filter/sort? Either
#                         > is fine with me — tell me which you prefer and then start the timer.
# Agent simulation trajectory event #17:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [THINK]
#                       > Natalia asks about inline vs separate feedback and to name the doc. For
#                       > efficiency and later sorting/filtering I prefer a separate 'Feedback' column
#                       > (keeps the sheet machine-readable and makes it easy to export to Canvas or
#                       > filter flagged items). I'll create a Google Doc (table) named "Lab grading
#                       > u00096u00096 first pass 2026-01-25" or a Google Sheet if she prefers a true
#                       > columnar layout — ask which she prefers. Plan: 1) she pastes the Canvas
#                       > rubric at the top and flags tricky reports, 2) I'll take roughly reports
#                       > 1-10 and draft the three-bullet feedback (praise, one improvement, next
#                       > step) in the Feedback column, 3) add a 'Flag' column for tricky or
#                       > borderline reports, 4) at the 45-minute mark we'll do a 3-5 minute check-in
#                       > and swap batches if needed. Ask whether she wants me to also insert inline
#                       > comments in each original report file, or keep feedback only in the table to
#                       > avoid duplication. Start the timer when she confirms the rubric is pasted
#                       > and she's ready.
# Agent simulation trajectory event #18:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [TALK]
#                       > Thanks — I prefer a separate 'Feedback' column (easier to filter/sort and
#                       > export). I'll create a shared doc now titled "Lab grading u00096u00096 first
#                       > pass 2026-01-25" (or I can make a Google Sheet if you want strict columns).
#                       > Proposed structure: Report ID | Student name | Link to report | Feedback
#                       > (three bullets: praise, one improvement, next step) | Flag (tricky) | Notes.
#                       > Workflow: you paste the Canvas rubric at the top and flag any tricky ones;
#                       > I'll take roughly the first ~10 reports and draft the three-bullet feedback
#                       > in the Feedback column while you skim for trends. At the 45-minute mark
#                       > we'll do a 3–5 minute check-in and swap or continue as needed. Quick
#                       > question: do you want me to also add inline comments directly in the
#                       > original reports, or keep feedback only in the table to avoid duplication?
#                       > If that sounds good, confirm whether you prefer a Doc (table) or a Sheet,
#                       > paste the rubric, and I will start the timer as soon as you say go and give
#                       > me edit access.
# Agent simulation trajectory event #19:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Marina Ellsworth acts: [DONE]
#                       > Waiting for your confirmation on Doc vs Sheet, the pasted rubric, and edit
#                       > access so I can create the file and start the 45-minute timer.
# Agent simulation trajectory event #20:
# >>>>>>>>> Date and time of events: 2026-01-25T19:35:09.939466
# Natalia Carmichael --> Marina Ellsworth: [CONVERSATION]
#                         > Lovely — please give me edit access (that will be easiest). The document
#                         > name you suggested is fine. Quick notes: First, paste the Canvas rubric at
#                         > the top and I will add my copy as well so success criteria are visible.
#                         > Then, could you add a short 'Feedback' column (rather than burying
#                         > comments inline) so we can sort and filter the three-bullet feedback
#                         > easily? Please also flag any reports you already think are tricky and list
#                         > any materials that might need department approval or a substitute.
#                         > Finally, start the 5-minute check-in timer when you share the link and
#                         > I’ll join and paste my accessibility notes and learning-objective
#                         > suggestions. Ready when you are — thank you!
# The last agent simulation trajectory event number was 20, thus the current number of the NEXT POTENTIAL TRAJECTORY
# EVENT is 21.
# **** END SIMULATION TRAJECTORY FOR Marina Ellsworth ****

# %%
reducer = ResultsReducer()

def aux_extract_content(focus_agent: TinyPerson, source_agent:TinyPerson, target_agent:TinyPerson, kind:str, event: str, content: str, timestamp:str):

    if event == "TALK":
        author = focus_agent.name
    elif event == "CONVERSATION":
        if source_agent is None:
            author = "USER"
        else:
            author = source_agent.name
    else:
        raise ValueError(f"Unknown event: {event}")
    
    
    entry = (author, content)
    print(entry)
    return entry
    


reducer.add_reduction_rule("TALK", aux_extract_content)
reducer.add_reduction_rule("CONVERSATION", aux_extract_content)

# %% [markdown]
# Finally, we obtain the dataframe with the data and save it to a `.csv`, for later use in other applications.

# %%
df = reducer.reduce_agent_to_dataframe(people[0], column_names=["author", "content"])
df
# Out:
# ('USER', 'Get some work done together, help each other.')
# ('Marina Ellsworth', 'Sounds good — I’m up for a focused co-working session. Quick proposal: a 90‑minute block (or 2×45 Pomodoros) with this agenda: 1) pick 1–2 priority tasks and clarify the desired outcome, 2) pair on the highest‑priority/hardest item for the first 45–60 minutes, 3) 10–15 minute check‑in to capture decisions and next steps. I can help draft requirements, map acceptance criteria, clean or outline data steps, review text, or sketch next actions. What would you like to work on first, and do you prefer 90 minutes or two 45‑minute rounds? If that works, I’ll open a shared doc and set a timer.')
# ('Natalia Carmichael', "Yes — I'd love to. First we will do a quick 5-minute check-in to agree priorities. Then we will do a focused work block (I suggest 25 minutes with a 5-minute break, then a second 25-minute block) — that usually helps me stay on task. My priorities right now are grading a stack of lab reports and finalising a Monday diffusion/osmosis lesson; either of those would be great to tackle together. I can open a shared Google Doc or my Canvas folder and share the rubric so we can work in parallel. Does that plan suit you? Which task would you prefer to start with, and do you prefer 25/5 Pomodoros or a single 50-minute block?")
# ('Marina Ellsworth', 'Sounds great — I like the 5‑minute check‑in + 25/5/25 rhythm. I suggest we start with finalizing your Monday diffusion/osmosis lesson (time‑sensitive), unless you’d rather begin with the grading stack. Proposed plan for the first 25‑minute block (I can take the lead drafting these):\n\n1) Confirm 1–2 clear learning objectives for Monday (what students should be able to DO). \n2) Sketch a 15–20 minute core activity (hands‑on demo or guided simulation) and a 5‑minute exit ticket question to assess learning. \n3) Make a short materials/tech checklist and a note about accessibility/accommodations. \n4) Jot a very brief teacher script/slide notes and any quick formative assessment items.\n\nAfter the first 25 minutes we’ll take the 5‑minute break, then use the second 25‑minute block to refine the activity, turn the exit ticket into an assessment item, or switch to grading if you prefer.\n\nPracticals: do you want me to open a Google Doc, or will you share a Canvas page? If Google Doc works, I can create an outline and paste in a quick template; if you prefer Canvas, please share the link. Once you share, I’ll start a 5‑minute check‑in (confirm the single priority and roles) and then start the first 25‑minute timer.')
# ('Natalia Carmichael', "Lovely — that plan suits me. First we will do a 90-minute block made of two focused 45-minute rounds, then a 10–15 minute check-in to capture decisions and next steps. My suggestion for priorities: start with grading the lab reports (they're the most urgent), then use the second 45 to finalise Monday's diffusion/osmosis lesson. Acceptance criteria so we're aligned: for grading, I'll aim for a first-pass on ~20 reports with my three-bullet feedback structure (praise, one improvement, next step) or at least complete the first pass on the stack and flag any tricky ones; for the lesson, I'd like finished slides, a materials list, and a short exit ticket uploaded to Canvas. Could you open a shared Google Doc and set a 45-minute timer to start? I can paste my rubric from Canvas into the doc and work in parallel — would you prefer to draft comments while I skim for trends, or should we split by batches and swap responsibility after the first round?")
# ('Marina Ellsworth', 'That plan sounds good — I can do the Google Doc and kick off the first 45-minute timer. My suggested workflow to keep us coordinated: 1) You paste the rubric at the top of the doc and flag any reports you already see as tricky. 2) I’ll draft the three-bullet feedback (praise, one improvement, next step) for roughly the first ~10 reports while you skim for trends and paste any global notes. 3) At the 45-minute mark we’ll do a quick 3–5 minute check-in in the doc: capture tricky ones, swap batches if needed, or finish the pass. That should get you a solid first pass on the stack; if the pile is larger we can adjust in the midpoint. I’ll create the doc now and share the link here — do you want me to name the doc “Lab grading — first pass [date]” and start the timer when you confirm? ')
# ('Natalia Carmichael', 'Lovely — the 25/5/25 rhythm suits me and I agree we should start with the Monday diffusion/osmosis lesson. First, can you open a Google Doc and share the link? I’ll paste the Canvas rubric into it so we have the success criteria visible. Roles for the first 25-minute block: please take the lead drafting the 15–20 minute core activity (hands-on demo or guided simulation) and a provisional materials/tech checklist; I’ll draft 1–2 clear learning objectives, note accessibility/accommodations, and add a brief teacher script/slide notes. Acceptance criteria for the first 25: agreed learning objectives, a sketched core activity, and a materials checklist (flag any missing or tricky supplies). Then in the second 25-minute block I’ll turn the exit ticket into a formative assessment item and assemble 3–6 slides + a short teacher script while you refine the activity and check logistics. Finally, we’ll use the short check-in after both blocks to capture decisions and upload the exit ticket/slides to Canvas. Ready for you to open the Doc and start a 5-minute check-in/timer?')
# ('Marina Ellsworth', 'Ready — I will open a Google Doc now and share the link here. I\'ll name it "Diffusion_Osmosis_Monday_2026-01-25" and paste a short outline that includes: 1) a 5-minute check-in note, 2) roles (I draft the 15–20-minute core activity + materials/tech checklist; you draft 1–2 learning objectives, accessibility notes, and teacher script), 3) acceptance criteria for the first 25 (agreed objectives, sketched core activity, materials checklist), and 4) the 25/5/25 timer plan. After I post the link, I’ll start the 5-minute check-in timer. Do you want me to give you edit access (preferred) or view-only? Any quick notes to add before I create the doc?')
# ('Natalia Carmichael', 'Lovely — that sounds perfect. Yes, please name the doc "Lab grading u000du000a— first pass 2026-01-25" (or similar) and share the link when it\'s ready; start the timer when you confirm. First, I\'ll paste the Canvas rubric at the top and flag any reports I already see as tricky. I\'ll skim for trends while you draft the three-bullet feedback for the first ~10 reports (praise, one improvement, next step). Acceptance criteria for this first pass: aim to complete a first-pass on the stack (rough target ~20 reports) with three-bullet feedback or at least finish the portion we agree on and flag tricky ones for a second pass. One quick preference question: do you want the three-bullet comments inline beneath each report, or in a separate \'Feedback\' column so we can filter/sort? Either is fine with me — tell me which you prefer and then start the timer.')
# ('Marina Ellsworth', 'Thanks — I prefer a separate \'Feedback\' column (easier to filter/sort and export). I\'ll create a shared doc now titled "Lab grading u00096u00096 first pass 2026-01-25" (or I can make a Google Sheet if you want strict columns). Proposed structure: Report ID | Student name | Link to report | Feedback (three bullets: praise, one improvement, next step) | Flag (tricky) | Notes. Workflow: you paste the Canvas rubric at the top and flag any tricky ones; I\'ll take roughly the first ~10 reports and draft the three-bullet feedback in the Feedback column while you skim for trends. At the 45-minute mark we\'ll do a 3–5 minute check-in and swap or continue as needed. Quick question: do you want me to also add inline comments directly in the original reports, or keep feedback only in the table to avoid duplication? If that sounds good, confirm whether you prefer a Doc (table) or a Sheet, paste the rubric, and I will start the timer as soon as you say go and give me edit access.')
# ('Natalia Carmichael', "Lovely — please give me edit access (that will be easiest). The document name you suggested is fine. Quick notes: First, paste the Canvas rubric at the top and I will add my copy as well so success criteria are visible. Then, could you add a short 'Feedback' column (rather than burying comments inline) so we can sort and filter the three-bullet feedback easily? Please also flag any reports you already think are tricky and list any materials that might need department approval or a substitute. Finally, start the 5-minute check-in timer when you share the link and I’ll join and paste my accessibility notes and learning-objective suggestions. Ready when you are — thank you!")
#                 author                                            content
# 0                 USER      Get some work done together, help each other.
# 1     Marina Ellsworth  Sounds good — I’m up for a focused co-working ...
# 2   Natalia Carmichael  Yes — I'd love to. First we will do a quick 5-...
# 3     Marina Ellsworth  Sounds great — I like the 5‑minute check‑in + ...
# 4   Natalia Carmichael  Lovely — that plan suits me. First we will do ...
# 5     Marina Ellsworth  That plan sounds good — I can do the Google Do...
# 6   Natalia Carmichael  Lovely — the 25/5/25 rhythm suits me and I agr...
# 7     Marina Ellsworth  Ready — I will open a Google Doc now and share...
# 8   Natalia Carmichael  Lovely — that sounds perfect. Yes, please name...
# 9     Marina Ellsworth  Thanks — I prefer a separate 'Feedback' column...
# 10  Natalia Carmichael  Lovely — please give me edit access (that will...

# %%
df.to_csv("../data/extractions/synthetic_data_generation.out.csv", index=False)
